# %% [markdown]
# <a href="https://colab.research.google.com/github/Moustafa-Rashidy/Coswara-Data/blob/master/App_inception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.applications.inception_v3 import decode_predictions

# %%
# load image
image = load_img('/content/1_ne8pqysxw4k1EJ_asfwS5w.jpeg',target_size=(299,299))
# conver image pixels to numpy array
image = img_to_array(image)
# image reshape
image = image.reshape(1,image.shape[0],image.shape[1],image.shape[2])
# image preprossece
image = preprocess_input(image)

# %%
# load model
model = InceptionV3()

# %%
# predict the probability across all input
yhat = model.predict(image)
# convert the probability to class labels
label = decode_predictions(yhat) 
# retrieve the most likely result
label = label [0][0]
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff236636ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# print the classification 
print('%s (%.2f%%)'%(label[1],label[2]*100))
from IPython.display import Image
Image('/content/1_ne8pqysxw4k1EJ_asfwS5w.jpeg')
Image('/content/1_ne8pqysxw4k1EJ_asfwS5w.jpeg',width = 299,height=299)
# Out:
# airliner (63.93%)
